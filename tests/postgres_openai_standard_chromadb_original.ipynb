# %% [markdown]
# ## Setup

# %%
# %pip install 'vanna[chromadb,openai,postgres]'
# Out:
# Requirement already satisfied: vanna[chromadb,openai,postgres] in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (0.7.6)
# Requirement already satisfied: requests in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (2.32.3)
# Requirement already satisfied: tabulate in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (0.9.0)
# Requirement already satisfied: plotly in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (6.0.0)
# Requirement already satisfied: pandas in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (2.2.3)
# Requirement already satisfied: sqlparse in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (0.5.3)
# Requirement already satisfied: kaleido in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (0.2.1)
# Requirement already satisfied: flask in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (3.1.0)
# Requirement already satisfied: flask-sock in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (0.7.0)
# Requirement already satisfied: flasgger in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (0.9.7.1)
# Requirement already satisfied: sqlalchemy in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (2.0.39)
# Requirement already satisfied: chromadb in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (0.6.3)
# Requirement already satisfied: openai in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (1.66.3)
# Requirement already satisfied: psycopg2-binary in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (2.9.10)
# Requirement already satisfied: db-dtypes in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from vanna[chromadb,openai,postgres]) (1.4.2)
# Requirement already satisfied: build>=1.0.3 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (2.10.6)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (0.115.11)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai,postgres]) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (3.21.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (1.31.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (0.52b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (1.31.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from chromadb->vanna[chromadb,openai,postgres]) (13.9.4)
# Requirement already satisfied: packaging>=17.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from db-dtypes->vanna[chromadb,openai,postgres]) (24.2)
# Requirement already satisfied: pyarrow>=3.0.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from db-dtypes->vanna[chromadb,openai,postgres]) (19.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pandas->vanna[chromadb,openai,postgres]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pandas->vanna[chromadb,openai,postgres]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pandas->vanna[chromadb,openai,postgres]) (2025.1)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flasgger->vanna[chromadb,openai,postgres]) (4.23.0)
# Requirement already satisfied: mistune in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flasgger->vanna[chromadb,openai,postgres]) (3.1.3)
# Requirement already satisfied: six>=1.10.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flasgger->vanna[chromadb,openai,postgres]) (1.17.0)
# Requirement already satisfied: Werkzeug>=3.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flask->vanna[chromadb,openai,postgres]) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flask->vanna[chromadb,openai,postgres]) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flask->vanna[chromadb,openai,postgres]) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flask->vanna[chromadb,openai,postgres]) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flask->vanna[chromadb,openai,postgres]) (1.9.0)
# Requirement already satisfied: simple-websocket>=0.5.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flask-sock->vanna[chromadb,openai,postgres]) (1.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from openai->vanna[chromadb,openai,postgres]) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from openai->vanna[chromadb,openai,postgres]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from openai->vanna[chromadb,openai,postgres]) (0.9.0)
# Requirement already satisfied: sniffio in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from openai->vanna[chromadb,openai,postgres]) (1.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from plotly->vanna[chromadb,openai,postgres]) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests->vanna[chromadb,openai,postgres]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests->vanna[chromadb,openai,postgres]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests->vanna[chromadb,openai,postgres]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests->vanna[chromadb,openai,postgres]) (2025.1.31)
# Requirement already satisfied: pyproject_hooks in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from build>=1.0.3->chromadb->vanna[chromadb,openai,postgres]) (1.2.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb->vanna[chromadb,openai,postgres]) (0.46.1)
# Requirement already satisfied: httpcore==1.* in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb->vanna[chromadb,openai,postgres]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->vanna[chromadb,openai,postgres]) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask->vanna[chromadb,openai,postgres]) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,openai,postgres]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,openai,postgres]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,openai,postgres]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from jsonschema>=3.0.1->flasgger->vanna[chromadb,openai,postgres]) (0.23.1)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai,postgres]) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai,postgres]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai,postgres]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai,postgres]) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->vanna[chromadb,openai,postgres]) (0.9)
# Requirement already satisfied: coloredlogs in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai,postgres]) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai,postgres]) (25.2.10)
# Requirement already satisfied: protobuf in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai,postgres]) (5.29.4)
# Requirement already satisfied: sympy in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai,postgres]) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,openai,postgres]) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,openai,postgres]) (7.2.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,openai,postgres]) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,openai,postgres]) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->vanna[chromadb,openai,postgres]) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,openai,postgres]) (0.52b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.52b1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,openai,postgres]) (0.52b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,openai,postgres]) (0.52b1)
# Requirement already satisfied: opentelemetry-util-http==0.52b1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,openai,postgres]) (0.52b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,openai,postgres]) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->vanna[chromadb,openai,postgres]) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb->vanna[chromadb,openai,postgres]) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb->vanna[chromadb,openai,postgres]) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,openai,postgres]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pydantic>=1.9->chromadb->vanna[chromadb,openai,postgres]) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from rich>=10.11.0->chromadb->vanna[chromadb,openai,postgres]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from rich>=10.11.0->chromadb->vanna[chromadb,openai,postgres]) (2.19.1)
# Requirement already satisfied: wsproto in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from simple-websocket>=0.5.1->flask-sock->vanna[chromadb,openai,postgres]) (1.2.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb->vanna[chromadb,openai,postgres]) (0.29.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from typer>=0.9.0->chromadb->vanna[chromadb,openai,postgres]) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai,postgres]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai,postgres]) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai,postgres]) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai,postgres]) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb->vanna[chromadb,openai,postgres]) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,openai,postgres]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,openai,postgres]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,openai,postgres]) (4.9)
# Requirement already satisfied: filelock in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,openai,postgres]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->vanna[chromadb,openai,postgres]) (2025.3.0)
# Requirement already satisfied: zipp>=0.5 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->vanna[chromadb,openai,postgres]) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->vanna[chromadb,openai,postgres]) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai,postgres]) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb->vanna[chromadb,openai,postgres]) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->vanna[chromadb,openai,postgres]) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from vanna.openai import OpenAI_Chat
from vanna.base import VannaBase
from vanna.chromadb import ChromaDB_VectorStore

# %%
import os
from openai import OpenAI

class DeepseekLLM(VannaBase):
    def __init__(self, config=None):
        if config is None:
            raise ValueError(
                "对于 Deepseek，必须提供包含 api_key 和 model 的配置"
            )

        if "api_key" not in config:
            raise ValueError("配置必须包含 Deepseek api_key")

        if "model" not in config:
            raise ValueError("配置必须包含 Deepseek model")

        if "base_url" not in config:
            raise ValueError("配置必须包含 Deepseek base_url")

        api_key = config["api_key"]
        self.model = config["model"]
        base_url = config["base_url"]
        self.client = OpenAI(api_key=api_key, base_url=base_url)

    def system_message(self, message: str) -> any:
        return {"role": "system", "content": message}

    def user_message(self, message: str) -> any:
        return {"role": "user", "content": message}

    def assistant_message(self, message: str) -> any:
        return {"role": "assistant", "content": message}

    def generate_sql(self, question: str, **kwargs) -> str:
        # 使用父类的 generate_sql
        sql = super().generate_sql(question, **kwargs)

        # 替换 "\_" 为 "_"
        sql = sql.replace("\\_", "_")

        return sql

    def submit_prompt(self, prompt, **kwargs) -> str:
        chat_response = self.client.chat.completions.create(
            model=self.model,
            messages=prompt,
        )

        return chat_response.choices[0].message.content

class MyVanna(ChromaDB_VectorStore, DeepseekLLM):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        DeepseekLLM.__init__(self, config=config)

vn = MyVanna(config={
    "api_key": "sk-",
    "model": "deepseek-v3-baidu",
    "base_url": "https://api.302.ai/v1"
})

# %%
vn.connect_to_postgres(host='localhost', dbname='postgres', user='postgres', password='123456', port='5432')

# %% [markdown]
# ## Training
# You only need to train once. Do not train again unless you want to add more training data.

# %%
# The information schema query may need some tweaking depending on your database. This is a good starting point.
df_information_schema = vn.run_sql("SELECT * FROM INFORMATION_SCHEMA.COLUMNS")

# This will break up the information schema into bite-sized chunks that can be referenced by the LLM
plan = vn.get_training_plan_generic(df_information_schema)
plan

# If you like the plan, then uncomment this and run it to train
# vn.train(plan=plan)
# Out:
# Train on Information Schema: postgres.pg_catalog pg_type
# Train on Information Schema: postgres.pg_catalog pg_class
# Train on Information Schema: postgres.pg_catalog pg_stat_ssl
# Train on Information Schema: postgres.pg_catalog pg_index
# Train on Information Schema: postgres.pg_catalog pg_stat_progress_create_index
# Train on Information Schema: postgres.pg_catalog pg_attribute
# Train on Information Schema: postgres.pg_catalog pg_shseclabel
# Train on Information Schema: postgres.pg_catalog pg_collation
# Train on Information Schema: postgres.pg_catalog pg_indexes
# Train on Information Schema: postgres.pg_catalog pg_database
# Train on Information Schema: postgres.pg_catalog pg_amproc
# Train on Information Schema: postgres.pg_catalog pg_stat_database
# Train on Information Schema: postgres.pg_catalog pg_stat_io
# Train on Information Schema: postgres.pg_catalog pg_default_acl
# Train on Information Schema: postgres.pg_catalog pg_stat_user_tables
# Train on Information Schema: postgres.pg_catalog pg_largeobject
# Train on Information Schema: postgres.pg_catalog pg_statio_sys_tables
# Train on Information Schema: postgres.pg_catalog pg_shadow
# Train on Information Schema: postgres.pg_catalog pg_locks
# Train on Information Schema: postgres.pg_catalog pg_available_extensions
# Train on Information Schema: postgres.pg_catalog pg_stat_bgwriter
# Train on Information Schema: postgres.pg_catalog pg_user_mappings
# Train on Information Schema: postgres.pg_catalog pg_ts_config
# Train on Information Schema: postgres.pg_catalog pg_stat_all_tables
# Train on Information Schema: postgres.pg_catalog pg_stat_sys_tables
# Train on Information Schema: postgres.pg_catalog pg_cast
# Train on Information Schema: postgres.pg_catalog pg_enum
# Train on Information Schema: postgres.pg_catalog pg_stat_xact_user_functions
# Train on Information Schema: postgres.pg_catalog pg_stat_sys_indexes
# Train on Information Schema: postgres.pg_catalog pg_stat_activity
# Train on Information Schema: postgres.pg_catalog pg_stat_replication
# Train on Information Schema: postgres.pg_catalog pg_rewrite
# Train on Information Schema: postgres.pg_catalog pg_depend
# Train on Information Schema: postgres.pg_catalog pg_available_extension_versions
# Train on Information Schema: postgres.pg_catalog pg_tables
# Train on Information Schema: postgres.pg_catalog pg_sequence
# Train on Information Schema: postgres.pg_catalog pg_stat_checkpointer
# Train on Information Schema: postgres.pg_catalog pg_largeobject_metadata
# Train on Information Schema: postgres.pg_catalog pg_hba_file_rules
# Train on Information Schema: postgres.pg_catalog pg_stat_wal_receiver
# Train on Information Schema: postgres.pg_catalog pg_statio_user_indexes
# Train on Information Schema: postgres.pg_catalog pg_subscription
# Train on Information Schema: postgres.pg_catalog pg_statio_user_tables
# Train on Information Schema: postgres.pg_catalog pg_policy
# Train on Information Schema: postgres.pg_catalog pg_publication_tables
# Train on Information Schema: postgres.pg_catalog pg_sequences
# Train on Information Schema: postgres.pg_catalog pg_stats_ext
# Train on Information Schema: postgres.pg_catalog pg_stat_all_indexes
# Train on Information Schema: postgres.pg_catalog pg_foreign_server
# Train on Information Schema: postgres.pg_catalog pg_trigger
# Train on Information Schema: postgres.pg_catalog pg_file_settings
# Train on Information Schema: postgres.pg_catalog pg_stat_xact_sys_tables
# Train on Information Schema: postgres.pg_catalog pg_stat_user_indexes
# Train on Information Schema: postgres.pg_catalog pg_event_trigger
# Train on Information Schema: postgres.pg_catalog pg_stat_progress_basebackup
# Train on Information Schema: postgres.pg_catalog pg_stats_ext_exprs
# Train on Information Schema: postgres.pg_catalog pg_user
# Train on Information Schema: postgres.pg_catalog pg_auth_members
# Train on Information Schema: postgres.pg_catalog pg_replication_slots
# Train on Information Schema: postgres.pg_catalog pg_attrdef
# Train on Information Schema: postgres.pg_catalog pg_settings
# Train on Information Schema: postgres.pg_catalog pg_stat_database_conflicts
# Train on Information Schema: postgres.pg_catalog pg_stat_progress_analyze
# Train on Information Schema: postgres.pg_catalog pg_ident_file_mappings
# Train on Information Schema: postgres.pg_catalog pg_seclabel
# Train on Information Schema: postgres.pg_catalog pg_aggregate
# Train on Information Schema: postgres.pg_catalog pg_ts_template
# Train on Information Schema: postgres.pg_catalog pg_proc
# Train on Information Schema: postgres.pg_catalog pg_authid
# Train on Information Schema: postgres.pg_catalog pg_stat_gssapi
# Train on Information Schema: postgres.pg_catalog pg_stat_wal
# Train on Information Schema: postgres.pg_catalog pg_prepared_statements
# Train on Information Schema: postgres.pg_catalog pg_statio_all_tables
# Train on Information Schema: postgres.pg_catalog pg_tablespace
# Train on Information Schema: postgres.pg_catalog pg_constraint
# Train on Information Schema: postgres.pg_catalog pg_stat_xact_user_tables
# Train on Information Schema: postgres.pg_catalog pg_shdepend
# Train on Information Schema: postgres.pg_catalog pg_statistic
# Train on Information Schema: postgres.pg_catalog pg_description
# Train on Information Schema: postgres.pg_catalog pg_operator
# Train on Information Schema: postgres.pg_catalog pg_publication_rel
# Train on Information Schema: postgres.pg_catalog pg_stat_xact_all_tables
# Train on Information Schema: postgres.pg_catalog pg_cursors
# Train on Information Schema: postgres.pg_catalog pg_language
# Train on Information Schema: postgres.pg_catalog pg_transform
# Train on Information Schema: postgres.pg_catalog pg_ts_parser
# Train on Information Schema: postgres.pg_catalog pg_timezone_names
# Train on Information Schema: postgres.pg_catalog pg_statio_all_indexes
# Train on Information Schema: postgres.pg_catalog pg_stats
# Train on Information Schema: postgres.pg_catalog pg_db_role_setting
# Train on Information Schema: postgres.pg_catalog pg_statistic_ext
# Train on Information Schema: postgres.pg_catalog pg_replication_origin_status
# Train on Information Schema: postgres.pg_catalog pg_stat_recovery_prefetch
# Train on Information Schema: postgres.pg_catalog pg_extension
# Train on Information Schema: postgres.pg_catalog pg_foreign_data_wrapper
# Train on Information Schema: postgres.pg_catalog pg_seclabels
# Train on Information Schema: postgres.pg_catalog pg_amop
# Train on Information Schema: postgres.pg_catalog pg_backend_memory_contexts
# Train on Information Schema: postgres.pg_catalog pg_stat_progress_cluster
# Train on Information Schema: postgres.pg_catalog pg_publication
# Train on Information Schema: postgres.pg_catalog pg_opclass
# Train on Information Schema: postgres.pg_catalog pg_policies
# Train on Information Schema: postgres.pg_catalog pg_matviews
# Train on Information Schema: postgres.pg_catalog pg_stat_subscription
# Train on Information Schema: postgres.pg_catalog pg_replication_origin
# Train on Information Schema: postgres.pg_catalog pg_stat_user_functions
# Train on Information Schema: postgres.pg_catalog pg_conversion
# Train on Information Schema: postgres.pg_catalog pg_partitioned_table
# Train on Information Schema: postgres.pg_catalog pg_stat_progress_vacuum
# Train on Information Schema: postgres.pg_catalog pg_range
# Train on Information Schema: postgres.pg_catalog pg_roles
# Train on Information Schema: postgres.pg_catalog pg_stat_slru
# Train on Information Schema: postgres.pg_catalog pg_stat_archiver
# Train on Information Schema: postgres.pg_catalog pg_user_mapping
# Train on Information Schema: postgres.pg_catalog pg_stat_replication_slots
# Train on Information Schema: postgres.pg_catalog pg_statio_sys_indexes
# Train on Information Schema: postgres.pg_catalog pg_publication_namespace
# Train on Information Schema: postgres.pg_catalog pg_stat_progress_copy
# Train on Information Schema: postgres.pg_catalog pg_ts_dict
# Train on Information Schema: postgres.pg_catalog pg_parameter_acl
# Train on Information Schema: postgres.pg_catalog pg_statistic_ext_data
# Train on Information Schema: postgres.pg_catalog pg_statio_user_sequences
# Train on Information Schema: postgres.pg_catalog pg_group
# Train on Information Schema: postgres.pg_catalog pg_statio_sys_sequences
# Train on Information Schema: postgres.pg_catalog pg_wait_events
# Train on Information Schema: postgres.pg_catalog pg_statio_all_sequences
# Train on Information Schema: postgres.pg_catalog pg_inherits
# Train on Information Schema: postgres.pg_catalog pg_ts_config_map
# Train on Information Schema: postgres.pg_catalog pg_init_privs
# Train on Information Schema: postgres.pg_catalog pg_foreign_table
# Train on Information Schema: postgres.pg_catalog pg_rules
# Train on Information Schema: postgres.pg_catalog pg_namespace
# Train on Information Schema: postgres.pg_catalog pg_stat_subscription_stats
# Train on Information Schema: postgres.pg_catalog pg_views
# Train on Information Schema: postgres.pg_catalog pg_prepared_xacts
# Train on Information Schema: postgres.pg_catalog pg_opfamily
# Train on Information Schema: postgres.pg_catalog pg_am
# Train on Information Schema: postgres.pg_catalog pg_shmem_allocations
# Train on Information Schema: postgres.pg_catalog pg_timezone_abbrevs
# Train on Information Schema: postgres.pg_catalog pg_shdescription
# Train on Information Schema: postgres.pg_catalog pg_subscription_rel
# Train on Information Schema: postgres.pg_catalog pg_config
# Train on Information Schema: postgres.public order_detail
# Train on Information Schema: postgres.public evisit_order
# Train on Information Schema: postgres.public new_fact_order_detail
# Train on Information Schema: postgres.public fact_order_detail
# Train on Information Schema: postgres.public mytable
# Train on Information Schema: postgres.information_schema view_routine_usage
# Train on Information Schema: postgres.information_schema triggers
# Train on Information Schema: postgres.information_schema sequences
# Train on Information Schema: postgres.information_schema transforms
# Train on Information Schema: postgres.information_schema table_constraints
# Train on Information Schema: postgres.information_schema _pg_foreign_servers
# Train on Information Schema: postgres.information_schema columns
# Train on Information Schema: postgres.information_schema foreign_data_wrappers
# Train on Information Schema: postgres.information_schema routine_privileges
# Train on Information Schema: postgres.information_schema sql_parts
# Train on Information Schema: postgres.information_schema domain_constraints
# Train on Information Schema: postgres.information_schema user_defined_types
# Train on Information Schema: postgres.information_schema foreign_table_options
# Train on Information Schema: postgres.information_schema tables
# Train on Information Schema: postgres.information_schema _pg_user_mappings
# Train on Information Schema: postgres.information_schema routines
# Train on Information Schema: postgres.information_schema referential_constraints
# Train on Information Schema: postgres.information_schema column_privileges
# Train on Information Schema: postgres.information_schema usage_privileges
# Train on Information Schema: postgres.information_schema domains
# Train on Information Schema: postgres.information_schema role_udt_grants
# Train on Information Schema: postgres.information_schema column_domain_usage
# Train on Information Schema: postgres.information_schema routine_table_usage
# Train on Information Schema: postgres.information_schema role_column_grants
# Train on Information Schema: postgres.information_schema user_mappings
# Train on Information Schema: postgres.information_schema schemata
# Train on Information Schema: postgres.information_schema foreign_tables
# Train on Information Schema: postgres.information_schema attributes
# Train on Information Schema: postgres.information_schema element_types
# Train on Information Schema: postgres.information_schema key_column_usage
# Train on Information Schema: postgres.information_schema role_routine_grants
# Train on Information Schema: postgres.information_schema role_table_grants
# Train on Information Schema: postgres.information_schema views
# Train on Information Schema: postgres.information_schema domain_udt_usage
# Train on Information Schema: postgres.information_schema administrable_role_authorizations
# Train on Information Schema: postgres.information_schema foreign_servers
# Train on Information Schema: postgres.information_schema column_udt_usage
# Train on Information Schema: postgres.information_schema view_column_usage
# Train on Information Schema: postgres.information_schema udt_privileges
# Train on Information Schema: postgres.information_schema check_constraints
# Train on Information Schema: postgres.information_schema _pg_foreign_tables
# Train on Information Schema: postgres.information_schema sql_sizing
# Train on Information Schema: postgres.information_schema parameters
# Train on Information Schema: postgres.information_schema role_usage_grants
# Train on Information Schema: postgres.information_schema constraint_column_usage
# Train on Information Schema: postgres.information_schema routine_column_usage
# Train on Information Schema: postgres.information_schema triggered_update_columns
# Train on Information Schema: postgres.information_schema sql_features
# Train on Information Schema: postgres.information_schema routine_sequence_usage
# Train on Information Schema: postgres.information_schema _pg_foreign_data_wrappers
# Train on Information Schema: postgres.information_schema view_table_usage
# Train on Information Schema: postgres.information_schema character_sets
# Train on Information Schema: postgres.information_schema check_constraint_routine_usage
# Train on Information Schema: postgres.information_schema applicable_roles
# Train on Information Schema: postgres.information_schema routine_routine_usage
# Train on Information Schema: postgres.information_schema table_privileges
# Train on Information Schema: postgres.information_schema user_mapping_options
# Train on Information Schema: postgres.information_schema collation_character_set_applicability
# Train on Information Schema: postgres.information_schema column_options
# Train on Information Schema: postgres.information_schema constraint_table_usage
# Train on Information Schema: postgres.information_schema collations
# Train on Information Schema: postgres.information_schema _pg_foreign_table_columns
# Train on Information Schema: postgres.information_schema data_type_privileges
# Train on Information Schema: postgres.information_schema column_column_usage
# Train on Information Schema: postgres.information_schema sql_implementation_info
# Train on Information Schema: postgres.information_schema foreign_server_options
# Train on Information Schema: postgres.information_schema foreign_data_wrapper_options
# Train on Information Schema: postgres.information_schema enabled_roles
# Train on Information Schema: postgres.information_schema information_schema_catalog_name

# %%
# The following are methods for adding training data. Make sure you modify the examples to match your database.

# DDL statements are powerful because they specify table names, colume names, types, and potentially relationships
vn.train(ddl="""
CREATE TABLE IF NOT EXISTS public.new_fact_order_detail
(
    order_no character varying(255) COLLATE pg_catalog."default",
    order_time timestamp without time zone,
    order_date date,
    brand_code character varying(255) COLLATE pg_catalog."default",
    program_code character varying(255) COLLATE pg_catalog."default",
    order_type integer,
    sales numeric(18,2),
    item_qty integer,
    item_price numeric(18,2),
    channel character varying(255) COLLATE pg_catalog."default",
    subchannel character varying(255) COLLATE pg_catalog."default",
    sub_subchannel character varying(255) COLLATE pg_catalog."default",
    material_code character varying(255) COLLATE pg_catalog."default",
    material_name_cn character varying(255) COLLATE pg_catalog."default",
    material_type character varying(255) COLLATE pg_catalog."default",
    merged_c_code character varying(255) COLLATE pg_catalog."default",
    tier_code character varying(255) COLLATE pg_catalog."default",
    first_order_date date,
    is_mtd_active_member_flag integer,
    ytd_active_arr character varying(255) COLLATE pg_catalog."default",
    r12_active_arr character varying(255) COLLATE pg_catalog."default",
    manager_counter_code character varying(255) COLLATE pg_catalog."default",
    ba_code character varying(255) COLLATE pg_catalog."default",
    province_name character varying(255) COLLATE pg_catalog."default",
    line_city_name character varying(255) COLLATE pg_catalog."default",
    line_city_level character varying(255) COLLATE pg_catalog."default",
    store_no character varying(255) COLLATE pg_catalog."default",
    terminal_name character varying(255) COLLATE pg_catalog."default",
    terminal_code character varying(255) COLLATE pg_catalog."default",
    terminal_region character varying(255) COLLATE pg_catalog."default",
    default_flag integer
)

TABLESPACE pg_default;

ALTER TABLE IF EXISTS public.new_fact_order_detail
    OWNER to postgres;

COMMENT ON COLUMN public.new_fact_order_detail.order_no
    IS '订单编号（核心主键）';

COMMENT ON COLUMN public.new_fact_order_detail.order_time
    IS '订单时间（精确到时间）';

COMMENT ON COLUMN public.new_fact_order_detail.order_date
    IS '订单日期（分析趋势或聚合）';

COMMENT ON COLUMN public.new_fact_order_detail.brand_code
    IS '品牌代码（关键分类维度）';

COMMENT ON COLUMN public.new_fact_order_detail.program_code
    IS '项目代码（分类维度）';

COMMENT ON COLUMN public.new_fact_order_detail.order_type
    IS '订单类型（正单/退单等）';

COMMENT ON COLUMN public.new_fact_order_detail.sales
    IS '销售额（核心指标）';

COMMENT ON COLUMN public.new_fact_order_detail.item_qty
    IS '商品数量（核心指标）';

COMMENT ON COLUMN public.new_fact_order_detail.item_price
    IS '单价（单项分析）';

COMMENT ON COLUMN public.new_fact_order_detail.channel
    IS '渠道（一级分类）';

COMMENT ON COLUMN public.new_fact_order_detail.subchannel
    IS '子渠道（二级分类）';

COMMENT ON COLUMN public.new_fact_order_detail.sub_subchannel
    IS '子渠道-细分（三级分类）';

COMMENT ON COLUMN public.new_fact_order_detail.material_code
    IS '产品代码（SKU分析）';

COMMENT ON COLUMN public.new_fact_order_detail.material_name_cn
    IS '产品名称（易读性）';

COMMENT ON COLUMN public.new_fact_order_detail.material_type
    IS '产品类型（分类维度）';

COMMENT ON COLUMN public.new_fact_order_detail.merged_c_code
    IS '顾客编号（客户行为分析）';

COMMENT ON COLUMN public.new_fact_order_detail.tier_code
    IS '会员等级代码（用户分层）';

COMMENT ON COLUMN public.new_fact_order_detail.first_order_date
    IS '首单日期（客户生命周期）';

COMMENT ON COLUMN public.new_fact_order_detail.is_mtd_active_member_flag
    IS 'MTD活跃客户标记（近期活跃分析）';

COMMENT ON COLUMN public.new_fact_order_detail.ytd_active_arr
    IS 'YTD活跃标记（年度活跃分析）';

COMMENT ON COLUMN public.new_fact_order_detail.r12_active_arr
    IS 'R12活跃标记（年度活跃分析）';

COMMENT ON COLUMN public.new_fact_order_detail.manager_counter_code
    IS '管理门店代码（业务归属）';

COMMENT ON COLUMN public.new_fact_order_detail.ba_code
    IS 'BA编号（关联员工表现）';

COMMENT ON COLUMN public.new_fact_order_detail.province_name
    IS '省份（地理维度）';

COMMENT ON COLUMN public.new_fact_order_detail.line_city_name
    IS '城市名称（地理维度）';

COMMENT ON COLUMN public.new_fact_order_detail.line_city_level
    IS '城市等级（地理维度）';

COMMENT ON COLUMN public.new_fact_order_detail.store_no
    IS '柜台编号（销售点）';

COMMENT ON COLUMN public.new_fact_order_detail.terminal_name
    IS '门店名称（易读性）';

COMMENT ON COLUMN public.new_fact_order_detail.terminal_code
    IS '门店代码（具体标识）';

COMMENT ON COLUMN public.new_fact_order_detail.terminal_region
    IS '区域（业务区域维度）';

COMMENT ON COLUMN public.new_fact_order_detail.default_flag
    IS '特殊订单标记（异常分析）';
""")
# Out:
# Adding ddl:
# CREATE TABLE IF NOT EXISTS public.new_fact_order_detail
# (
#     order_no character varying(255) COLLATE pg_catalog."default",
#     order_time timestamp without time zone,
#     order_date date,
#     brand_code character varying(255) COLLATE pg_catalog."default",
#     program_code character varying(255) COLLATE pg_catalog."default",
#     order_type integer,
#     sales numeric(18,2),
#     item_qty integer,
#     item_price numeric(18,2),
#     channel character varying(255) COLLATE pg_catalog."default",
#     subchannel character varying(255) COLLATE pg_catalog."default",
#     sub_subchannel character varying(255) COLLATE pg_catalog."default",
#     material_code character varying(255) COLLATE pg_catalog."default",
#     material_name_cn character varying(255) COLLATE pg_catalog."default",
#     material_type character varying(255) COLLATE pg_catalog."default",
#     merged_c_code character varying(255) COLLATE pg_catalog."default",
#     tier_code character varying(255) COLLATE pg_catalog."default",
#     first_order_date date,
#     is_mtd_active_member_flag integer,
#     ytd_active_arr character varying(255) COLLATE pg_catalog."default",
#     r12_active_arr character varying(255) COLLATE pg_catalog."default",
#     manager_counter_code character varying(255) COLLATE pg_catalog."default",
#     ba_code character varying(255) COLLATE pg_catalog."default",
#     province_name character varying(255) COLLATE pg_catalog."default",
#     line_city_name character varying(255) COLLATE pg_catalog."default",
#     line_city_level character varying(255) COLLATE pg_catalog."default",
#     store_no character varying(255) COLLATE pg_catalog."default",
#     terminal_name character varying(255) COLLATE pg_catalog."default",
#     terminal_code character varying(255) COLLATE pg_catalog."default",
#     terminal_region character varying(255) COLLATE pg_catalog."default",
#     default_flag integer
# )
#
# TABLESPACE pg_default;
#
# ALTER TABLE IF EXISTS public.new_fact_order_detail
#     OWNER to postgres;
#
# COMMENT ON COLUMN public.new_fact_order_detail.order_no
#     IS '订单编号（核心主键）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.order_time
#     IS '订单时间（精确到时间）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.order_date
#     IS '订单日期（分析趋势或聚合）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.brand_code
#     IS '品牌代码（关键分类维度）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.program_code
#     IS '项目代码（分类维度）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.order_type
#     IS '订单类型（正单/退单等）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.sales
#     IS '销售额（核心指标）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.item_qty
#     IS '商品数量（核心指标）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.item_price
#     IS '单价（单项分析）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.channel
#     IS '渠道（一级分类）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.subchannel
#     IS '子渠道（二级分类）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.sub_subchannel
#     IS '子渠道-细分（三级分类）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.material_code
#     IS '产品代码（SKU分析）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.material_name_cn
#     IS '产品名称（易读性）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.material_type
#     IS '产品类型（分类维度）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.merged_c_code
#     IS '顾客编号（客户行为分析）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.tier_code
#     IS '会员等级代码（用户分层）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.first_order_date
#     IS '首单日期（客户生命周期）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.is_mtd_active_member_flag
#     IS 'MTD活跃客户标记（近期活跃分析）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.ytd_active_arr
#     IS 'YTD活跃标记（年度活跃分析）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.r12_active_arr
#     IS 'R12活跃标记（年度活跃分析）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.manager_counter_code
#     IS '管理门店代码（业务归属）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.ba_code
#     IS 'BA编号（关联员工表现）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.province_name
#     IS '省份（地理维度）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.line_city_name
#     IS '城市名称（地理维度）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.line_city_level
#     IS '城市等级（地理维度）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.store_no
#     IS '柜台编号（销售点）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.terminal_name
#     IS '门店名称（易读性）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.terminal_code
#     IS '门店代码（具体标识）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.terminal_region
#     IS '区域（业务区域维度）';
#
# COMMENT ON COLUMN public.new_fact_order_detail.default_flag
#     IS '特殊订单标记（异常分析）';
# Add of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# Add of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# Add of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# Add of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# Add of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# Add of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# Add of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# Add of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# Insert of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# Add of existing embedding ID: 27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl
# '27ba6359-a260-5584-b0b5-58f91fe89cc5-ddl'

# %%
# 添加相关的SQL训练数据以增强查询能力
vn.train(documentation="订单编号(order_no)是每个订单的唯一标识符，是表中最核心的字段。它用于追踪和唯一标识订单。")
vn.train(documentation="订单时间(order_time)记录了订单的具体时间，精确到秒，用于分析订单的时间分布和趋势。")
vn.train(documentation="订单日期(order_date)是订单的日期字段，用于根据日期进行聚合分析，发现销售和订单模式。")
vn.train(documentation="品牌代码(brand_code)用于标识商品的品牌，是分析品牌销售和市场份额的关键字段。")
vn.train(documentation="销售额(sales)字段记录了每个订单的销售总额，是衡量业务表现的核心指标。")
vn.train(documentation="商品数量(item_qty)记录了每个订单中商品的数量，是衡量销售数量和库存管理的重要数据。")
vn.train(documentation="商品单价(item_price)记录商品的单价，用于分析价格对销售的影响。")
vn.train(documentation="渠道(channel)字段表示订单的销售渠道，例如线上、电商、线下零售等，是分析不同销售渠道表现的依据。")
vn.train(documentation="子渠道(subchannel)是对渠道的细分，帮助深入分析具体的销售途径。")
vn.train(documentation="产品代码(material_code)是产品的唯一标识符，帮助分析产品的销售表现和库存情况。")
vn.train(documentation="产品名称(material_name_cn)记录产品的中文名称，提供易于阅读和理解的产品描述。")
vn.train(documentation="产品类型(material_type)用于标识产品的类别，例如电子产品、日用商品等，有助于进行产品分类分析。")
vn.train(documentation="顾客编号(merged_c_code)是每个顾客的唯一标识符，用于客户行为分析和生命周期管理。")
vn.train(documentation="会员等级代码(tier_code)用于标识顾客的会员等级，有助于进行会员分层和定向营销。")
vn.train(documentation="首单日期(first_order_date)记录了顾客的首单日期，是衡量客户生命周期和忠诚度的重要字段。")
vn.train(documentation="MTD活跃客户标记(is_mtd_active_member_flag)用于标识某一月份内活跃的客户，是客户活跃度分析的关键指标。")
vn.train(documentation="YTD活跃客户标记(ytd_active_arr)表示年度活跃客户标记，用于衡量顾客在年度内的活跃情况。")
vn.train(documentation="城市名称(line_city_name)记录了订单发生的城市名称，有助于进行地理维度的分析。")
vn.train(documentation="门店名称(terminal_name)是门店的名称，便于理解和分析不同门店的销售表现。")
vn.train(documentation="特殊订单标记(default_flag)标识是否为特殊订单，用于异常订单的分析和处理。")
# Out:
# Add of existing embedding ID: e51166bf-e9ec-5c3b-86d3-051efc5ac1fe-doc
# Add of existing embedding ID: 109cc57b-fdc6-5bdc-b322-ad0ec25f6cb1-doc
# Add of existing embedding ID: bd432e22-4daf-54d7-8b58-9d0b45dd65be-doc
# Add of existing embedding ID: a90a7bc9-384e-56d8-88a5-584b72ca1a04-doc
# Add of existing embedding ID: 5d236575-1044-5678-a388-d9e08ce45fb3-doc
# Add of existing embedding ID: 27e9a406-a3b7-583e-8d35-b072837dd025-doc
# Add of existing embedding ID: c7520444-8fc8-5f41-a87f-fe41597537b0-doc
# Add of existing embedding ID: db7250b8-45e9-5918-b2e8-6a485c3f996a-doc
# Add of existing embedding ID: 183bd864-de7b-5091-9a9c-bd17c91c986f-doc
# Add of existing embedding ID: bd6503a8-f78a-5d47-8bf6-9d43f23f5677-doc
# Add of existing embedding ID: e3d342c1-e1b6-5b51-8699-8796556fcc7d-doc
# Add of existing embedding ID: 0f6fe0db-d09c-52d8-88c8-91a096d23627-doc
# Add of existing embedding ID: 4be165e4-3fa0-5b7e-a27c-6f2611b09646-doc
# Add of existing embedding ID: 54c69e03-ba86-5c55-9893-6508a3603698-doc
# Add of existing embedding ID: ef605da0-e0b2-5a45-ac1b-66680d315ac7-doc
# Add of existing embedding ID: f6bd45a8-74e3-502c-a9a1-e7e76f455340-doc
# Add of existing embedding ID: fb8bb49a-36f8-5b45-90e9-038770f957ce-doc
# Add of existing embedding ID: f6ae75b8-9463-5ac6-aee5-83dcb23fafd1-doc
# Add of existing embedding ID: 80cf655d-3ce6-5c58-998e-95aa58b8e4c7-doc
# Add of existing embedding ID: 9d413782-514c-5b2f-bb80-b025ab517128-doc
# Add of existing embedding ID: d55e94f9-51cc-528e-a4e5-e9d7f67bf8ac-doc
# Add of existing embedding ID: fac4a31a-13ae-58ed-a046-3443396844f2-doc
# Add of existing embedding ID: 9cba9464-aee5-5029-8610-848137526fdf-doc
# Add of existing embedding ID: 1eb5e5b1-1888-5c74-af05-fa8c6ab38d37-doc
# Add of existing embedding ID: 22151b35-92eb-528e-bbc8-07acf47e9a49-doc
# Add of existing embedding ID: 2ddd6304-3df1-5c71-9113-d491eab0fc8e-doc
# Add of existing embedding ID: 3a46f525-2f85-5eb5-81f4-c32d5d597012-doc
# Add of existing embedding ID: 47bbd95d-c248-50a9-b07f-94c47ae9bc25-doc
# Add of existing embedding ID: 865a4fc5-5e45-5bcb-a52a-64c02b195d87-doc
# Add of existing embedding ID: 1ae526b5-c52b-5b84-8e68-6d264ca8da34-doc
# Add of existing embedding ID: 57090202-98a4-5bf2-88d3-94dfa5cd8a65-doc
# Add of existing embedding ID: 3005c300-6dc4-5b3f-bde0-56b04d35b813-doc
# Add of existing embedding ID: 2d71fac9-fab4-5f89-a400-5bcf6ea4bb12-doc
# Add of existing embedding ID: c05679c2-496f-5097-860a-eea5fa8e6ab0-doc
# Add of existing embedding ID: 8253a6ee-678e-538a-a3e5-8280503691cd-doc
# Add of existing embedding ID: cfa6e654-e9f2-5926-bc66-2cc80759f26f-doc
# Add of existing embedding ID: 3437e453-e01a-5cfa-a998-52ab445b0278-doc
# Add of existing embedding ID: b44c1e2a-4c2e-5e44-98f1-df9022127eb2-doc
# Add of existing embedding ID: bfff065a-f9a3-581d-abce-4306d8093e19-doc
# Add of existing embedding ID: 4e10b678-954d-555b-b93f-9d4fb8c5f759-doc
# Add of existing embedding ID: 6c53d741-8d6d-5207-932f-3801d8d30920-doc
# Add of existing embedding ID: 10f79474-5797-5201-a49e-2744924c047b-doc
# Add of existing embedding ID: 1f54b68e-9d32-5310-9cf8-3327a6f751a0-doc
# Add of existing embedding ID: 881609e8-e3d0-55af-8a24-92f364c03b48-doc
# Add of existing embedding ID: ec3ed5c2-fe84-524f-b38b-2b38231af4a3-doc
# Add of existing embedding ID: 758a7f44-6548-5de0-ad44-9995cb3cbd55-doc
# Add of existing embedding ID: 0dfac0f6-e7c8-54eb-b880-b772d568a14c-doc
# Add of existing embedding ID: 358ad8b7-3303-5d2a-8d6c-71011c199c34-doc
# Add of existing embedding ID: defc404b-7cf0-51a6-85a8-ad3486228ff8-doc
# Add of existing embedding ID: ded4b283-2b8c-5e5f-8fa8-e775cd1ca7be-doc
# Add of existing embedding ID: ca6a328b-f710-51e1-8b34-d96e65b9eae5-doc
# Add of existing embedding ID: e9d7b9a7-3fe4-54d3-8efe-a95cdc6e124a-doc
# Add of existing embedding ID: 985328cc-e4c1-5bc3-bfe1-8e53078df3fc-doc
# Add of existing embedding ID: f1a1ebec-f291-5ac9-b9c7-fcdd3c55acf4-doc
# Add of existing embedding ID: 99791c48-fc4b-5d11-9d7a-9e96495bf237-doc
# Add of existing embedding ID: 8f60c1ee-22de-5506-bbd0-f143fc07b4ae-doc
# Add of existing embedding ID: 15ecb442-0590-5701-85f2-9c1a261b9db0-doc
# Add of existing embedding ID: 2caa60a7-3e27-523e-a4d2-aaefd7333fb6-doc
# Add of existing embedding ID: 4e08dd6e-1f3e-5b28-9ead-42791228a3cc-doc
# Add of existing embedding ID: 4fd2c456-cb65-5e54-afdd-993327fdf83c-doc
# Add of existing embedding ID: 990ad00b-37ee-524b-9726-ecc9db5bcc51-doc
# Add of existing embedding ID: 0c051218-87b2-56ba-bc4e-f85116c0e1da-doc
# Add of existing embedding ID: 04e1cd97-b777-5ab0-9299-5427be6a4987-doc
# Add of existing embedding ID: 8506cb92-e53f-55bd-b103-a091da7b49ab-doc
# Add of existing embedding ID: 745ed2af-885a-51b8-8fe7-136dbde490db-doc
# Add of existing embedding ID: 31c363ec-7129-5c45-8d8b-a3a52ec432ed-doc
# Add of existing embedding ID: 1f508c38-a2e9-5a64-a049-51e0986a7478-doc
# Add of existing embedding ID: df0cc261-1ff2-5b65-9d03-3e208dc75d5f-doc
# Add of existing embedding ID: 80499f87-59be-59b3-8f68-762a3733bc28-doc
# Add of existing embedding ID: 7a6e1797-1710-5d8e-98de-15d9cf6f67d4-doc
# Add of existing embedding ID: a030fa46-d1e9-5ea8-82f7-40fcf21cf1a5-doc
# Add of existing embedding ID: 1c222a7d-44c0-58f6-9c27-317eccee12bd-doc
# Add of existing embedding ID: 959ff5db-cf39-5026-a8a3-815eb95fd728-doc
# Add of existing embedding ID: 82f954a8-d4f0-5696-a002-e51710897658-doc
# Add of existing embedding ID: 38b11631-0f63-57b9-81d9-73b3769aa344-doc
# Add of existing embedding ID: 1bdf5958-76d0-5eb8-bd6c-78ce600d59d8-doc
# Add of existing embedding ID: ea46ccf9-54b0-5419-9233-57dbb2bf4c9a-doc
# Add of existing embedding ID: a4ce2d98-c254-53ec-a655-7ea8c99c75b1-doc
# Add of existing embedding ID: d16c4491-1f26-53a5-ad0d-9eee7dbf7381-doc
# Add of existing embedding ID: 72cdad5e-90f4-5d34-afc7-38373c1333ad-doc
# Add of existing embedding ID: 7677a523-7ca2-5fc2-bdc2-defb5609feb8-doc
# Add of existing embedding ID: 186152c6-b51f-5b5d-a71b-aa529dfd9a48-doc
# Add of existing embedding ID: 0b58b77d-42d6-5b91-96fa-8b131b9049d5-doc
# Add of existing embedding ID: be1d06e9-b024-51e0-97f1-ad409674afa5-doc
# Add of existing embedding ID: 148c823e-7770-50b4-8cb9-741d30099221-doc
# Add of existing embedding ID: 75537320-1d94-5d5c-9b06-2dae8b65ae88-doc
# Add of existing embedding ID: 9cfa4862-9938-5bc2-8844-da00f3f0b47d-doc
# Add of existing embedding ID: 8fa53bf6-1dfe-566e-b497-d57d5a92b21a-doc
# Add of existing embedding ID: 176e063e-b8e5-5152-84cb-b00e4da3845c-doc
# Add of existing embedding ID: b6987a08-1eb6-5aac-9db0-88ab55c643dd-doc
# Add of existing embedding ID: 4cc58e1f-4918-5c72-adc2-f4e8b39b27be-doc
# Add of existing embedding ID: a6e97728-b459-58c3-9e0f-7a03969cc6a6-doc
# Add of existing embedding ID: abb58de8-6ca8-5b33-b0b6-afa2ce5a3a9f-doc
# Add of existing embedding ID: 3b2a5ff2-b095-5180-a9ca-080ef8723a70-doc
# Add of existing embedding ID: 3337ef47-7a16-5021-8763-2026494c44d6-doc
# Add of existing embedding ID: bbcbafef-8da9-58d2-b5c3-ced1c0833eab-doc
# Add of existing embedding ID: d4923720-cdcc-5ed3-ae98-a9321743fb65-doc
# Add of existing embedding ID: 0e21cda7-ffef-544d-b033-8d0c398e7ff9-doc
# Add of existing embedding ID: 6c5bb8a2-d1f0-516c-bd30-b1533c18f6cc-doc
# Add of existing embedding ID: 9739be86-0965-51a7-84a3-33b7fca66b9e-doc
# Add of existing embedding ID: d749a30a-0fe2-557e-9abd-739f9f9f8e4f-doc
# Add of existing embedding ID: cad9a0cd-1923-5e86-bd21-5fd4ce69fd26-doc
# Add of existing embedding ID: decc71f4-e3c9-59f2-9d4d-f77e2d6305e3-doc
# Add of existing embedding ID: fb1d7913-a36d-52ad-a09c-74cf4fdd88c8-doc
# Add of existing embedding ID: 3271c88c-b6da-5d1d-a988-c441c8546839-doc
# Add of existing embedding ID: 08befc8c-d3a5-5275-8192-57fbc499c87c-doc
# Add of existing embedding ID: 87416263-dd78-5278-b057-fc7eb8686b0f-doc
# Add of existing embedding ID: 8acf006b-0a3f-575b-be36-fe19c1b48313-doc
# Add of existing embedding ID: 8e79ac30-cc93-5bf5-a5b0-f83764877599-doc
# Add of existing embedding ID: 4c22aca3-774a-50b4-a375-dd4b2dbca971-doc
# Add of existing embedding ID: 7a24c457-0843-5e8d-97a4-4f2ad6d625ed-doc
# Add of existing embedding ID: 3ce06457-5fe0-539e-88b4-6c957635a5ab-doc
# Add of existing embedding ID: 9bdcb7dc-e291-59ae-a9eb-f3b97a226605-doc
# Add of existing embedding ID: 1fcf6e22-20a8-5f7a-a07a-670b2f5980ba-doc
# Add of existing embedding ID: 2657d753-3c5f-5bb7-90ff-d7ec950d691c-doc
# Add of existing embedding ID: 10a764e8-f2ea-53d1-858e-dccc06587847-doc
# Add of existing embedding ID: bd44f9cb-22e1-52e0-bee6-dc04e0f7c34c-doc
# Add of existing embedding ID: 56d81788-fd1d-5873-afcf-6e38af77f1eb-doc
# Add of existing embedding ID: 3fdfed61-0fec-51f7-9ed2-195725b60cff-doc
# Add of existing embedding ID: b4bd9f2b-2fbd-54d1-8e84-1cb579d25c8f-doc
# Add of existing embedding ID: 1a1de044-d4f7-59c3-8630-9e83ca441ec9-doc
# Add of existing embedding ID: 603318e2-cf77-5a7a-8c5d-04e135a633c7-doc
# Add of existing embedding ID: f9ed474e-e294-5bb2-a695-f3f35e782eec-doc
# Add of existing embedding ID: 87d49801-5cbb-58b3-99b4-2cfdd09340ce-doc
# Add of existing embedding ID: 27bbc9c5-2630-5a7b-9e51-9f4b1383a01d-doc
# Add of existing embedding ID: d1ea9314-63b1-5c5c-82d3-7bed50c3a903-doc
# Add of existing embedding ID: a0b237d5-02f6-5456-beae-b80abc5d8810-doc
# Add of existing embedding ID: 827d9532-5f4f-5ca3-83c3-91394c836d45-doc
# Add of existing embedding ID: 7e6e61cd-f387-5884-b055-fb461a5d373e-doc
# Add of existing embedding ID: 33e31fa0-d2ba-5f66-83aa-121c75ac31d1-doc
# Add of existing embedding ID: 17b50499-ac98-546d-986f-0f48636ca5d3-doc
# Add of existing embedding ID: d2a006e7-4401-5f1f-b3d9-db4acd8a0fef-doc
# Add of existing embedding ID: eb58a92c-4952-52f2-9e49-625c47a2d5f0-doc
# Add of existing embedding ID: 1132cffa-13e6-57b4-873d-558c7eb63b4a-doc
# Add of existing embedding ID: 6d11a73a-8047-559c-bb0c-8e3814e839b1-doc
# Add of existing embedding ID: 0bd582fb-892a-54a4-9fe2-7dd0100bca1c-doc
# Add of existing embedding ID: 82ad6a84-f3ad-521f-8e64-70aa77d0ff5c-doc
# Add of existing embedding ID: 446f6efc-898c-5b7a-838a-bc77c127d92a-doc
# Add of existing embedding ID: 4ba99493-3969-518f-82f1-4ad2a4cbbcca-doc
# Add of existing embedding ID: 6b961605-599b-508b-afa3-92112854ee13-doc
# Add of existing embedding ID: 45d5c32f-0a57-5374-81fe-14adadc90252-doc
# Add of existing embedding ID: 693235fa-f9e1-5094-b7be-d40a36e4df45-doc
# Add of existing embedding ID: 641a7e3c-2e63-5aeb-a4da-39efa5dfb3ba-doc
# Add of existing embedding ID: f9512e2f-4326-5c55-9307-460049474897-doc
# Add of existing embedding ID: 6992cfbf-aa0d-5672-b8b9-928eeefd5e3f-doc
# Add of existing embedding ID: 96be5022-16e5-5c2d-8aa3-6085ede3b052-doc
# Add of existing embedding ID: ea4be43a-9ab8-57a9-9c17-cdd66ee27d61-doc
# Add of existing embedding ID: 063ee6af-a1b3-5a51-ac1d-629720cbbd9b-doc
# Add of existing embedding ID: 8207dc38-2077-5803-947b-fb53e52b5b63-doc
# Add of existing embedding ID: aad30589-7877-5e74-92f3-585bcd3d817b-doc
# Add of existing embedding ID: a55f73c1-7966-5211-ad2c-cdfe535262b8-doc
# Add of existing embedding ID: 851d9804-0bb8-5e94-a66d-f2e2ecd7d0fa-doc
# Add of existing embedding ID: b7da5b7c-9cd7-5965-9880-7e8badc2bad3-doc
# Add of existing embedding ID: 0305df7c-9234-56ba-a05c-a1d38691e212-doc
# Add of existing embedding ID: 10744470-b05f-5f4f-a062-43ffd955f028-doc
# Add of existing embedding ID: 7b46b8f5-3765-5059-9e8c-783864e0cd98-doc
# Add of existing embedding ID: c5873e69-67c3-5cdd-aa75-88fc5b4ffed4-doc
# Add of existing embedding ID: 72e456be-dd32-5444-bdc5-0e2c65907591-doc
# Add of existing embedding ID: 29b03ce2-2d88-5594-9bcc-e410c2b75fc2-doc
# Add of existing embedding ID: 46029cb5-0c52-5b57-a4e3-c0d8662e7911-doc
# Add of existing embedding ID: 5949711d-8671-5bba-be68-c4ef1409919f-doc
# Add of existing embedding ID: 32772453-354f-5bd1-a409-cf70fb91abdc-doc
# Add of existing embedding ID: d52c3e96-bcdb-5d4e-a890-6aa66cdfc54f-doc
# Add of existing embedding ID: 8039fe99-2642-5361-bb10-6e2671831fae-doc
# Add of existing embedding ID: a75898c6-6796-552f-b31f-a2bdfa8ce9d7-doc
# Add of existing embedding ID: 0aae0142-0c36-51f3-8267-5a70d0ac08a0-doc
# Add of existing embedding ID: 28920a7b-0bdd-596b-864a-6bc9f75ce340-doc
# Add of existing embedding ID: 04ef967d-17cf-537e-9ca4-4b4302cc1d7b-doc
# Add of existing embedding ID: 4f608791-cd98-547c-9a66-530d525e1362-doc
# Add of existing embedding ID: 5fa05cfe-d201-5f8a-b573-3f7910ef7ab7-doc
# Add of existing embedding ID: 5f411ea2-0417-5450-9e8c-3f8a196ccb20-doc
# Add of existing embedding ID: 7a10f9ac-2811-56bb-a691-ceffd4b87ee2-doc
# Add of existing embedding ID: aff8441e-b8a9-58a3-85b3-3691d4b68695-doc
# Add of existing embedding ID: c3c129a1-9aa5-5ad9-9cda-22129e172223-doc
# Add of existing embedding ID: 4fcb099b-d01c-5d9e-91e0-acce6b1123e3-doc
# Add of existing embedding ID: 87162ac6-1ab4-5091-8d16-5f4f6cb64d2d-doc
# Add of existing embedding ID: b3236984-33f3-53b2-b93e-580f0f652442-doc
# Add of existing embedding ID: 820b5a6f-bc63-505d-b748-c244bc9febc9-doc
# Add of existing embedding ID: 26d21384-fb48-5c56-9d23-82b0760f3069-doc
# Add of existing embedding ID: b4c838ea-b45f-5286-8c48-cb5189a9597c-doc
# Add of existing embedding ID: 21c6b35f-4c18-5b68-ba8a-cf1deda0c566-doc
# Add of existing embedding ID: b780a735-8848-5972-a0d2-e92e77ae235f-doc
# Add of existing embedding ID: 62138dec-cecd-5226-8297-f3d4e12eaa64-doc
# Add of existing embedding ID: bcb914dd-4e1c-59ff-a626-51584d42ab3a-doc
# Add of existing embedding ID: 7d2f48d4-4432-511c-94b7-3bafef083bbe-doc
# Add of existing embedding ID: 0184ad1d-f2d1-5829-922d-122078705a83-doc
# Add of existing embedding ID: 88a6d5df-e834-50b6-8dc6-252050effc90-doc
# Add of existing embedding ID: 50d75dc3-292b-503a-80a4-c4593ea3a1fb-doc
# Add of existing embedding ID: fc2899fc-d8ae-573a-896b-f3db762d6c7f-doc
# Add of existing embedding ID: 6be1b68c-3a67-5365-9495-157882eb2ee1-doc
# Add of existing embedding ID: 5555f468-0ce4-5820-a436-624a62b44388-doc
# Add of existing embedding ID: 0719d3c6-f11f-5855-aea5-0c08fd45d651-doc
# Add of existing embedding ID: ce981929-1da2-56dc-8290-9ca6ba9ce7e6-doc
# Add of existing embedding ID: 7d37e54e-0f91-5c31-b269-cb700dc240f0-doc
# Add of existing embedding ID: 52b57e26-e63a-5bfe-9f18-cb81821fd6cd-doc
# Add of existing embedding ID: 80ecd84b-66a9-5709-959d-7c6dc7b55eda-doc
# Add of existing embedding ID: 7e02a51b-7bed-55ff-aba5-c2b4b9362fde-doc
# Add of existing embedding ID: 160aef02-e184-5f84-a599-c45e30451be4-doc
# Add of existing embedding ID: 892cef78-3489-54fa-8917-508abcba7f47-doc
# Add of existing embedding ID: ae310a58-badb-5542-b566-867d071bc794-doc
# Add of existing embedding ID: bf671aef-27b2-5787-a90d-ee7d199cb18c-doc
# Add of existing embedding ID: ab98f08b-43f6-5667-a183-9c8c1beae6fb-doc
# Add of existing embedding ID: 2752d67c-ee90-5410-999d-99030dd36741-doc
# Add of existing embedding ID: fbd86c84-3e8c-532e-94d2-e75e7374b3f6-doc
# Add of existing embedding ID: 2319a7cf-8229-5db6-90df-12d25cf8886f-doc
# Add of existing embedding ID: da66697c-0648-5377-9d81-6e036ff92b4b-doc
# Add of existing embedding ID: 939e53c9-cf39-58cd-bbf4-d429970aeb4d-doc
# Add of existing embedding ID: 8d10bda3-f967-56e2-917d-69a0216df526-doc
# Add of existing embedding ID: 496dd609-03f5-595e-a06e-fb271b1d4c0a-doc
# Add of existing embedding ID: 9e1754ba-31f1-5871-8131-26f19b524e33-doc
# Add of existing embedding ID: e050148e-1706-5862-bd07-e4140ff13589-doc
# Add of existing embedding ID: eb930cb8-011b-566e-b45a-24c099db5616-doc
# Add of existing embedding ID: 3ac1fb0d-e4dd-5c77-9d48-85f437997dd0-doc
# Add of existing embedding ID: 6aebb9de-801f-5867-88fa-67ec0ceb7b91-doc
# Add of existing embedding ID: ac3720f5-f298-51b1-b8b4-6d54ac1067e8-doc
# Add of existing embedding ID: ef4a7a09-45bc-5fc1-b609-9152440d0f6a-doc
# Add of existing embedding ID: 1d8c9610-8a44-59c8-be05-9a85c9bb470c-doc
# Add of existing embedding ID: b7acb8fa-5ebb-5534-a0c6-0d641e36067f-doc
# Add of existing embedding ID: 011e2c3a-895e-5a1f-bea3-5625ae1401ad-doc
# Add of existing embedding ID: 49905ef1-e2a6-5d04-982d-ec4ed9b71354-doc
# Add of existing embedding ID: 4ee3ac8c-e9eb-5f34-82d8-744a7daf994b-doc
# Add of existing embedding ID: 6838f6c9-285a-50ff-98b9-3130dfa5f79e-doc
# Add of existing embedding ID: 21fce156-0763-5508-81d7-b93fd106e3ec-doc
# Add of existing embedding ID: 1e77b818-79e1-5c7a-a92c-1c96cc4ffb12-doc
# Add of existing embedding ID: d8a15a07-ddf0-53a1-8072-a0da90ac1db3-doc
# Add of existing embedding ID: 2f5e03fe-8c61-5f6c-999f-91e0d30494e1-doc
# Add of existing embedding ID: 26b3078a-c6f5-5187-8fd3-2ac33a640ea7-doc
# Add of existing embedding ID: 76c97a42-5e20-549a-88b7-a687288f1db6-doc
# Add of existing embedding ID: 092454fa-a261-590b-b476-c2b8be0c154d-doc
# Add of existing embedding ID: c17afe4c-7936-5426-9179-1d2cc14f66e0-doc
# Add of existing embedding ID: 0596ace1-ebda-5f25-9d89-7d8d5cfd699e-doc
# Add of existing embedding ID: a4887882-ea84-5637-832d-534428e5fe74-doc
# Add of existing embedding ID: ed4fdd5d-0425-502a-bd8b-3fe43ed42410-doc
# Add of existing embedding ID: 3876ec6e-4aa5-54cb-8fa1-457399dc3c8c-doc
# Add of existing embedding ID: 758302a0-b01b-582f-a9f8-de54efcd5cec-doc
# Add of existing embedding ID: 0eeac9f2-809d-53d9-8b55-0f5241841d51-doc
# Add of existing embedding ID: e51166bf-e9ec-5c3b-86d3-051efc5ac1fe-doc
# Add of existing embedding ID: 109cc57b-fdc6-5bdc-b322-ad0ec25f6cb1-doc
# Add of existing embedding ID: bd432e22-4daf-54d7-8b58-9d0b45dd65be-doc
# Add of existing embedding ID: a90a7bc9-384e-56d8-88a5-584b72ca1a04-doc
# Add of existing embedding ID: 51cf1d6d-7637-5b87-b9e7-31c577fbde59-doc
# Add of existing embedding ID: 4ee3ac8c-e9eb-5f34-82d8-744a7daf994b-doc
# Insert of existing embedding ID: 4ee3ac8c-e9eb-5f34-82d8-744a7daf994b-doc
# Add of existing embedding ID: 6838f6c9-285a-50ff-98b9-3130dfa5f79e-doc
# Insert of existing embedding ID: 6838f6c9-285a-50ff-98b9-3130dfa5f79e-doc
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Add of existing embedding ID: 21fce156-0763-5508-81d7-b93fd106e3ec-doc
# Insert of existing embedding ID: 21fce156-0763-5508-81d7-b93fd106e3ec-doc
# Add of existing embedding ID: 1e77b818-79e1-5c7a-a92c-1c96cc4ffb12-doc
# Insert of existing embedding ID: 1e77b818-79e1-5c7a-a92c-1c96cc4ffb12-doc
# Add of existing embedding ID: d8a15a07-ddf0-53a1-8072-a0da90ac1db3-doc
# Insert of existing embedding ID: d8a15a07-ddf0-53a1-8072-a0da90ac1db3-doc
# Add of existing embedding ID: 2f5e03fe-8c61-5f6c-999f-91e0d30494e1-doc
# Insert of existing embedding ID: 2f5e03fe-8c61-5f6c-999f-91e0d30494e1-doc
# Add of existing embedding ID: 26b3078a-c6f5-5187-8fd3-2ac33a640ea7-doc
# Insert of existing embedding ID: 26b3078a-c6f5-5187-8fd3-2ac33a640ea7-doc
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Add of existing embedding ID: 76c97a42-5e20-549a-88b7-a687288f1db6-doc
# Insert of existing embedding ID: 76c97a42-5e20-549a-88b7-a687288f1db6-doc
# Add of existing embedding ID: 092454fa-a261-590b-b476-c2b8be0c154d-doc
# Insert of existing embedding ID: 092454fa-a261-590b-b476-c2b8be0c154d-doc
# Add of existing embedding ID: c17afe4c-7936-5426-9179-1d2cc14f66e0-doc
# Insert of existing embedding ID: c17afe4c-7936-5426-9179-1d2cc14f66e0-doc
# Add of existing embedding ID: 0596ace1-ebda-5f25-9d89-7d8d5cfd699e-doc
# Insert of existing embedding ID: 0596ace1-ebda-5f25-9d89-7d8d5cfd699e-doc
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Add of existing embedding ID: a4887882-ea84-5637-832d-534428e5fe74-doc
# Insert of existing embedding ID: a4887882-ea84-5637-832d-534428e5fe74-doc
# Add of existing embedding ID: ed4fdd5d-0425-502a-bd8b-3fe43ed42410-doc
# Insert of existing embedding ID: ed4fdd5d-0425-502a-bd8b-3fe43ed42410-doc
# Add of existing embedding ID: 3876ec6e-4aa5-54cb-8fa1-457399dc3c8c-doc
# Insert of existing embedding ID: 3876ec6e-4aa5-54cb-8fa1-457399dc3c8c-doc
# Add of existing embedding ID: 758302a0-b01b-582f-a9f8-de54efcd5cec-doc
# Insert of existing embedding ID: 758302a0-b01b-582f-a9f8-de54efcd5cec-doc
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Add of existing embedding ID: 0eeac9f2-809d-53d9-8b55-0f5241841d51-doc
# Insert of existing embedding ID: 0eeac9f2-809d-53d9-8b55-0f5241841d51-doc
# Add of existing embedding ID: e51166bf-e9ec-5c3b-86d3-051efc5ac1fe-doc
# Insert of existing embedding ID: e51166bf-e9ec-5c3b-86d3-051efc5ac1fe-doc
# Add of existing embedding ID: 109cc57b-fdc6-5bdc-b322-ad0ec25f6cb1-doc
# Insert of existing embedding ID: 109cc57b-fdc6-5bdc-b322-ad0ec25f6cb1-doc
# Add of existing embedding ID: bd432e22-4daf-54d7-8b58-9d0b45dd65be-doc
# Insert of existing embedding ID: bd432e22-4daf-54d7-8b58-9d0b45dd65be-doc
# Add of existing embedding ID: a90a7bc9-384e-56d8-88a5-584b72ca1a04-doc
# Insert of existing embedding ID: a90a7bc9-384e-56d8-88a5-584b72ca1a04-doc
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# 'a90a7bc9-384e-56d8-88a5-584b72ca1a04-doc'

# %%
# 按品牌查询订单数据
vn.train(sql="SELECT order_no, order_time, sales, item_qty FROM public.new_fact_order_detail WHERE brand_code = 'ABC'")

# 按订单日期范围查询销售数据
vn.train(sql="SELECT order_no, order_date, sales, channel FROM public.new_fact_order_detail WHERE order_date BETWEEN '2025-01-01' AND '2025-03-31'")

# 计算每个省份的总销售额
vn.train(sql="SELECT province_name, SUM(sales) AS total_sales FROM public.new_fact_order_detail GROUP BY province_name")

# 查询活跃会员的订单数量
vn.train(sql="SELECT merged_c_code, tier_code, COUNT(order_no) AS total_orders FROM public.new_fact_order_detail WHERE is_mtd_active_member_flag = 1 GROUP BY merged_c_code, tier_code")

# 查询特定门店的订单详细信息
vn.train(sql="SELECT order_no, item_qty, item_price, terminal_name FROM public.new_fact_order_detail WHERE store_no = 'S123'")

# 按商品代码筛选订单
vn.train(sql="SELECT order_no, material_code, material_name_cn, item_qty FROM public.new_fact_order_detail WHERE material_code = 'P123'")

# 查找销售额大于500的订单
vn.train(sql="SELECT order_no, sales, order_date, channel FROM public.new_fact_order_detail WHERE sales > 500")

# 按省份分组查询订单数量
vn.train(sql="SELECT province_name, COUNT(order_no) AS order_count FROM public.new_fact_order_detail GROUP BY province_name")

# 获取特定顾客的订单详情
vn.train(sql="SELECT order_no, item_qty, sales, order_date FROM public.new_fact_order_detail WHERE merged_c_code = 'C001'")

# 获取某个城市的订单详情
vn.train(sql="SELECT order_no, sales, channel, item_qty FROM public.new_fact_order_detail WHERE line_city_name = 'Beijing'")

# 统计每个会员等级的总销售额
vn.train(sql="SELECT tier_code, SUM(sales) AS total_sales FROM public.new_fact_order_detail GROUP BY tier_code")

# 按日期查询每个商品的销售数据
vn.train(sql="SELECT material_code, material_name_cn, sales, order_date FROM public.new_fact_order_detail WHERE order_date = '2025-03-01'")

# 查询特定渠道的销售额
vn.train(sql="SELECT channel, SUM(sales) AS total_sales FROM public.new_fact_order_detail WHERE channel = 'Online' GROUP BY channel")

# 计算每个门店的订单总数
vn.train(sql="SELECT terminal_name, COUNT(order_no) AS order_count FROM public.new_fact_order_detail GROUP BY terminal_name")

# 获取退单数据
vn.train(sql="SELECT order_no, sales, item_qty FROM public.new_fact_order_detail WHERE order_type = 2")  # 假设2代表退单类型

# 根据客户的活跃状态查询订单数据
vn.train(sql="SELECT merged_c_code, order_no, sales, item_qty FROM public.new_fact_order_detail WHERE is_mtd_active_member_flag = 1")

# 按城市等级分组查询销售总额
vn.train(sql="SELECT line_city_level, SUM(sales) AS total_sales FROM public.new_fact_order_detail GROUP BY line_city_level")

# 查询特定产品类型的订单
vn.train(sql="SELECT order_no, material_type, sales FROM public.new_fact_order_detail WHERE material_type = 'Electronics'")

# 统计每月的销售额
vn.train(sql="SELECT EXTRACT(MONTH FROM order_date) AS month, SUM(sales) AS total_sales FROM public.new_fact_order_detail GROUP BY EXTRACT(MONTH FROM order_date)")

# 查询特定城市的活跃客户数量
vn.train(sql="SELECT line_city_name, COUNT(DISTINCT merged_c_code) AS active_customers FROM public.new_fact_order_detail WHERE is_mtd_active_member_flag = 1 GROUP BY line_city_name")
# Out:
# Add of existing embedding ID: c81b65db-c6b0-5e6c-8b5e-52b7fbf7aa0f-sql
# Insert of existing embedding ID: c81b65db-c6b0-5e6c-8b5e-52b7fbf7aa0f-sql
# Question generated with sql: What are the order numbers, order times, sales, and item quantities for orders associated with the brand 'ABC'?
# Adding SQL...
# Question generated with sql: What are the order numbers, dates, sales amounts, and channels for orders placed between January 1, 2025, and March 31, 2025?
# Adding SQL...
# Question generated with sql: What are the total sales for each province?
# Adding SQL...
# Question generated with sql: What is the total number of orders placed by active members, grouped by their merged customer code and tier code?
# Adding SQL...
# Question generated with sql: What are the order numbers, item quantities, item prices, and terminal names for all orders placed at store 'S123'?
# Adding SQL...
# Question generated with sql: What are the order numbers, material codes, material names in Chinese, and item quantities for the material with code 'P123'?
# Adding SQL...
# Question generated with sql: What are the details of orders where the sales amount exceeded $500?
# Adding SQL...
# Question generated with sql: What is the total number of orders placed in each province?
# Adding SQL...
# Question generated with sql: What are the order numbers, item quantities, sales amounts, and order dates for customer code 'C001'?
# Adding SQL...
# Question generated with sql: What are the order numbers, sales amounts, channels, and item quantities for orders placed in Beijing?
# Adding SQL...
# Question generated with sql: What is the total sales for each tier?
# Adding SQL...
# Question generated with sql: What are the material codes, material names in Chinese, and sales for orders placed on March 1, 2025?
# Adding SQL...
# Question generated with sql: What is the total sales generated through the Online channel?
# Adding SQL...
# Question generated with sql: What is the number of orders processed at each terminal?
# Adding SQL...
# Question generated with sql: What are the order numbers, sales amounts, and item quantities for orders of type 2?
# Adding SQL...
# Question generated with sql: "What are the merged customer code, order number, sales amount, and item quantity for all orders placed by active members for the current month?"
# Adding SQL...
# Question generated with sql: What is the total sales for each city level?
# Adding SQL...
# Question generated with sql: What are the order numbers, material types, and sales for orders that involve electronics?
# Adding SQL...
# Question generated with sql: "What is the total sales for each month?"
# Adding SQL...
# Question generated with sql: What are the number of active customers in each city?
# Adding SQL...
# '3da48f77-aa21-58fe-9192-40b8eb5ae672-sql'

# %%
# At any time you can inspect what training data the package is able to reference
training_data = vn.get_training_data()
training_data
# Out:
#                                            id  \
# 0    f91ceec2-1b82-54b6-9fe1-c30b5048bbff-sql
# 1    c81b65db-c6b0-5e6c-8b5e-52b7fbf7aa0f-sql
# 2    94b56fd4-5fb3-545c-b41c-8c2ccdf9064e-sql
# 3    0984926e-aa16-52e2-88d7-de8178962da3-sql
# 4    42960fa8-302d-54f3-9cda-e5748d7f101b-sql
# ..                                        ...
# 232  1d8c9610-8a44-59c8-be05-9a85c9bb470c-doc
# 233  b7acb8fa-5ebb-5534-a0c6-0d641e36067f-doc
# 234  011e2c3a-895e-5a1f-bea3-5625ae1401ad-doc
# 235  49905ef1-e2a6-5d04-982d-ec4ed9b71354-doc
# 236  51cf1d6d-7637-5b87-b9e7-31c577fbde59-doc
#
#                                               question  \
# 0    What are the details of the person named John ...
# 1    What are the order numbers, order times, sales...
# 2    What are the order numbers, dates, sales amoun...
# 3          What are the total sales for each province?
# 4    What is the total number of orders placed by a...
# ..                                                 ...
# 232                                               None
# 233                                               None
# 234                                               None
# 235                                               None
# 236                                               None
#
#                                                content training_data_type
# 0       SELECT * FROM my-table WHERE name = 'John Doe'                sql
# 1    SELECT order_no, order_time, sales, item_qty F...                sql
# 2    SELECT order_no, order_date, sales, channel FR...                sql
# 3    SELECT province_name, SUM(sales) AS total_sale...                sql
# 4    SELECT merged_c_code, tier_code, COUNT(order_n...                sql
# ..                                                 ...                ...
# 232  The following columns are in the foreign_serve...      documentation
# 233  The following columns are in the foreign_data_...      documentation
# 234  The following columns are in the enabled_roles...      documentation
# 235  The following columns are in the information_s...      documentation
# 236  Our business defines OTIF score as the percent...      documentation
#
# [259 rows x 4 columns]

# %%
# You can remove training data if there's obsolete/incorrect information.
vn.remove_training_data(id='1-ddl')

# %% [markdown]
# ## Asking the AI
# Whenever you ask a new question, it will find the 10 most relevant pieces of training data and use it as part of the LLM prompt to generate the SQL.

# %%
vn.ask(question=...)

# %% [markdown]
# ## Launch the User Interface
# ![vanna-flask](https://vanna.ai/blog/img/vanna-flask.gif)

# %%
from vanna.flask import VannaFlaskApp
app = VannaFlaskApp(vn)
app.run()
# Out:
# Your app is running at:
# http://localhost:8084
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: on
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# Add of existing embedding ID: a9dbcba8-eb0f-56ff-af40-1a69f5112d11-sql
# Insert of existing embedding ID: a9dbcba8-eb0f-56ff-af40-1a69f5112d11-sql
# Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# Traceback (most recent call last):
#   File "/Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages/vanna/base/base.py", line 2071, in get_plotly_figure
#     exec(plotly_code, globals(), ldict)
# TypeError: exec() arg 1 must be a string, bytes or code object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages/vanna/flask/__init__.py", line 692, in generate_plotly_figure
#     fig = vn.get_plotly_figure(plotly_code=code, df=df, dark_mode=False)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages/vanna/base/base.py", line 2093, in get_plotly_figure
#     fig = px.line(df)
#           ^^^^^^^^^^^
#   File "/Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages/plotly/express/_chart_types.py", line 270, in line
#     return make_figure(args=locals(), constructor=go.Scatter)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages/plotly/express/_core.py", line 2477, in make_figure
#     args = build_dataframe(args, constructor)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mikoo/.pyenv/versions/3.12.0/lib/python3.12/site-packages/plotly/express/_core.py", line 1779, in build_dataframe
#     raise ValueError(
# ValueError: Plotly Express cannot process wide-form data with columns of different type.
# Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1

# %% [markdown]
# ## Next Steps
# Using Vanna via Jupyter notebooks is great for getting started but check out additional customizable interfaces like the
# - [Streamlit app](https://github.com/vanna-ai/vanna-streamlit)
# - [Flask app](https://github.com/vanna-ai/vanna-flask)
# - [Slackbot](https://github.com/vanna-ai/vanna-slack)
